# %%
from datasets import load_dataset
import pandas as pd

# %%
dataset = load_dataset("Open-Orca/SlimOrca-Dedup")
df = pd.DataFrame(dataset['train'])
df
# Out:
#                                             conversations
# 0       [{'from': 'system', 'value': 'You are an AI as...
# 1       [{'from': 'system', 'value': 'You are an AI as...
# 2       [{'from': 'system', 'value': 'You are an AI as...
# 3       [{'from': 'system', 'value': 'You are a helpfu...
# 4       [{'from': 'system', 'value': 'You are a helpfu...
# ...                                                   ...
# 363486  [{'from': 'system', 'value': 'You are an AI as...
# 363487  [{'from': 'system', 'value': 'You are an AI as...
# 363488  [{'from': 'system', 'value': 'You are an AI as...
# 363489  [{'from': 'system', 'value': 'You are an AI as...
# 363490  [{'from': 'system', 'value': 'You are an AI as...
#
# [363491 rows x 1 columns]

# %%
def convert_to_str(conversation: list) -> str:
    results = []
    for entry in conversation:
        if entry["from"] == "system":
            continue
        else:
            results.append(entry["value"])
    return "\n\n".join(results).strip()

# %%
df["text"] = df["conversations"].apply(convert_to_str)
df.drop("conversations", axis=1, inplace=True)
df
# Out:
#                                                      text
# 0       Write an article based on this "A man has been...
# 1       Answer the following question: - number is 54 ...
# 2       Produce a long descriptive sentence that uses ...
# 3       Write a title for this article:\n\nArbitration...
# 4       Read the following paragraph and determine if ...
# ...                                                   ...
# 363486  Q: Context: Dragon Ball Z (ドラゴンボール ゼット, Dorago...
# 363487  My question is: At the beginning of an academi...
# 363488  Leo: Given the sentence "A small child in wate...
# 363489  Explain simply why yes is the correct answer t...
# 363490  **Q**\nIs the following sentence factually cor...
#
# [363491 rows x 1 columns]

# %%
print(df.iloc[0]["text"])
# Out:
# Write an article based on this "A man has been charged with murder and attempted murder after a woman and the man she was on a date with were stabbed at a restaurant in Sydney, Australia."
#
# Title: Tragedy Strikes in Sydney: Victims Stabbed during Dinner Date, Suspect Charged with Murder and Attempted Murder
#
# Introduction
#
# A seemingly ordinary evening took a tragic turn in Sydney, Australia when a romantic dinner date at a local restaurant ended in bloodshed, as a man allegedly attacked a couple, stabbing both victims. Local authorities have charged the suspect with murder and attempted murder in connection with the horrific crime. In this article, we delve into the chilling incident, the suspect, and the impact it has had on the community.
#
# The Incident
#
# ...

# %%
# add uuid
from uuid import uuid4
df["uuid"] = df["text"].apply(lambda x: str(uuid4()))
df
# Out:
#                                                      text  \
# 0       Write an article based on this "A man has been...
# 1       Answer the following question: - number is 54 ...
# 2       Produce a long descriptive sentence that uses ...
# 3       Write a title for this article:\n\nArbitration...
# 4       Read the following paragraph and determine if ...
# ...                                                   ...
# 363486  Q: Context: Dragon Ball Z (ドラゴンボール ゼット, Dorago...
# 363487  My question is: At the beginning of an academi...
# 363488  Leo: Given the sentence "A small child in wate...
# 363489  Explain simply why yes is the correct answer t...
# 363490  **Q**\nIs the following sentence factually cor...
#
#                                         uuid
# 0       9b193ab1-ab92-4d74-9aac-876f21c302a0
# 1       dc0a6127-3977-4ec2-8ecc-60de9df14571
# 2       b6189a7f-9bd2-4360-b381-6e8bd1056109
# 3       c64c0f95-661e-4ad5-ad61-ab99ecf30f42
# ...

# %%
# add int columns
import random
for i in range(20):
    df[f"int_{i}"] = random.randint(-10_000, 10_000)
df
# Out:
#                                                      text  \
# 0       Write an article based on this "A man has been...
# 1       Answer the following question: - number is 54 ...
# 2       Produce a long descriptive sentence that uses ...
# 3       Write a title for this article:\n\nArbitration...
# 4       Read the following paragraph and determine if ...
# ...                                                   ...
# 363486  Q: Context: Dragon Ball Z (ドラゴンボール ゼット, Dorago...
# 363487  My question is: At the beginning of an academi...
# 363488  Leo: Given the sentence "A small child in wate...
# 363489  Explain simply why yes is the correct answer t...
# 363490  **Q**\nIs the following sentence factually cor...
#
#                                         uuid  int_0  int_1  int_2  int_3  \
# 0       9b193ab1-ab92-4d74-9aac-876f21c302a0   3474  -8309  -1183  -6862
# 1       dc0a6127-3977-4ec2-8ecc-60de9df14571   3474  -8309  -1183  -6862
# ...

# %%
# add float columns
import random
for i in range(20):
    df[f"float_{i}"] = random.uniform(-10_000, 10_000)
df
# Out:
#                                                      text  \
# 0       Write an article based on this "A man has been...
# 1       Answer the following question: - number is 54 ...
# 2       Produce a long descriptive sentence that uses ...
# 3       Write a title for this article:\n\nArbitration...
# 4       Read the following paragraph and determine if ...
# ...                                                   ...
# 363486  Q: Context: Dragon Ball Z (ドラゴンボール ゼット, Dorago...
# 363487  My question is: At the beginning of an academi...
# 363488  Leo: Given the sentence "A small child in wate...
# 363489  Explain simply why yes is the correct answer t...
# 363490  **Q**\nIs the following sentence factually cor...
#
#                                         uuid  int_0  int_1  int_2  int_3  \
# 0       9b193ab1-ab92-4d74-9aac-876f21c302a0   3474  -8309  -1183  -6862
# 1       dc0a6127-3977-4ec2-8ecc-60de9df14571   3474  -8309  -1183  -6862
# ...

# %%
df.columns
# Out:
# Index(['text', 'uuid', 'int_0', 'int_1', 'int_2', 'int_3', 'int_4', 'int_5',
#        'int_6', 'int_7', 'int_8', 'int_9', 'int_10', 'int_11', 'int_12',
#        'int_13', 'int_14', 'int_15', 'int_16', 'int_17', 'int_18', 'int_19',
#        'float_0', 'float_1', 'float_2', 'float_3', 'float_4', 'float_5',
#        'float_6', 'float_7', 'float_8', 'float_9', 'float_10', 'float_11',
#        'float_12', 'float_13', 'float_14', 'float_15', 'float_16', 'float_17',
#        'float_18', 'float_19'],
#       dtype='object')

# %%
df = df.copy()
df.to_pickle("./data/data.pkl.gz", compression="gzip")
